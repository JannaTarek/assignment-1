# %% [markdown]
# <a href="https://colab.research.google.com/github/JannaTarek/assignment-1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
temperatures = [22, 24, 19, 23, 25, 27, 26]  # Example temperatures in °C
plt.figure(figsize=(10, 6))  # optional: makes the plot bigger
plt.plot(days, temperatures, marker='o', linestyle='-', color='b')
plt.title('Temperature Variation Over a Week')
plt.xlabel('Days of the Week')
plt.ylabel('Temperature (°C)')
plt.show()
